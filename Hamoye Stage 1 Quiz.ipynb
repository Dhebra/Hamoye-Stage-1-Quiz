# %%
import numpy as np
import pandas as pd

# %%
food_balance = pd.read_csv("C:\\Users\\Admi\\Downloads\\FoodBalance.csv", encoding = 'latin-1')
food_balance.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# # What is the total sum of Wine produced in 2015 and 2018 respectively?

# %%
wine_2015 = food_balance.groupby('Item')['Y2015'].sum()
wine_2015

#Total wine produced in 2015 is 4251.81
# Out:
# Item
# Alcohol, Non-Food        2180.00
# Alcoholic Beverages     98783.72
# Animal Products         11811.73
# Animal fats            200675.72
# Apples and products     10559.15
#                          ...
# Vegetables, Other      158104.08
# Vegetal Products       107064.17
# Wheat and products     234710.51
# Wine                     4251.81
# Yams                   203151.78
# Name: Y2015, Length: 119, dtype: float64

# %%
#What is the total sum of Wine produced in 2015 and 2018 respectively?

wine_2018 = food_balance.groupby('Item')['Y2018'].sum()
wine_2018

#Total wine produced in 2018 is 4039.09
# Out:
# Item
# Alcohol, Non-Food        2293.00
# Alcoholic Beverages     97847.27
# Animal Products         11578.61
# Animal fats            269648.27
# Apples and products      9640.51
#                          ...
# Vegetables, Other      163987.21
# Vegetal Products       107775.39
# Wheat and products     242645.19
# Wine                     4039.32
# Yams                   221272.09
# Name: Y2018, Length: 119, dtype: float64

# %% [markdown]
# # Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
y2017_area = food_balance[['Y2017', "Area"]]
y2017_area
# Out:
#           Y2017      Area
# 0      41389.00   Algeria
# 1          0.00   Algeria
# 2       3341.00   Algeria
# 3         92.82   Algeria
# 4         80.19   Algeria
# ...         ...       ...
# 60938     19.00  Zimbabwe
# 60939      1.33  Zimbabwe
# 60940      1.00  Zimbabwe
# 60941      0.04  Zimbabwe
# 60942      0.02  Zimbabwe
#
# [60943 rows x 2 columns]

# %%
highest_sum = food_balance.groupby("Area") ["Y2017"].sum()
highest_sum

#Nigeria has the highest sum in 2017
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %% [markdown]
# # Given the following python code, what would the output of the code give?

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [46], line 5
#       1 #Given the following python code, what would the output of the code give?
#       3 my_tuppy = (1,2,5,8)
# ----> 5 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
element = food_balance.groupby('Element').sum()
element

#the total number of the sum of Processing in 2017 is 292836.00
# Out:
# C:\Users\Admi\AppData\Local\Temp\ipykernel_7224\635840309.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   element = food_balance.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %% [markdown]
# # Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
stock_variation = food_balance.groupby('Element').sum()
stock_variation

#The year with the highest sum of Stock Variation is 2014
# Out:
# C:\Users\Admi\AppData\Local\Temp\ipykernel_7224\2421394943.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   stock_variation = food_balance.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %%
#What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

mean = food_balance.describe()
mean

#The mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places is: 140.92 and 1671.86
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# # How would you check for the number of rows and columns in a pandas DataFrame named df?

# %%
# how to check the number of rows and columns in a pandas DataFrame named df
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [50], line 2
#       1 # how to check the number of rows and columns in a pandas DataFrame named df
# ----> 2 df.shape
#
# NameError: name 'df' is not defined

# %% [markdown]
# # What is the total number of unique countries in the dataset?

# %%
unique_countries = food_balance["Area"].value_counts()
unique_countries

#the total number of unique countries in the dataset is 49
# Out:
# Kenya                          1560
# Egypt                          1488
# Nigeria                        1474
# Côte d'Ivoire                  1467
# Senegal                        1462
# Cameroon                       1460
# Uganda                         1458
# Zambia                         1451
# Malawi                         1447
# Ethiopia                       1447
# Madagascar                     1439
# Mozambique                     1427
# Rwanda                         1426
# Angola                         1424
# United Republic of Tanzania    1419
# Congo                          1413
# Guinea                         1410
# Burkina Faso                   1409
# Niger                          1403
# South Africa                   1399
# Zimbabwe                       1393
# Morocco                        1393
# Mauritius                      1378
# Botswana                       1378
# Ghana                          1354
# Central African Republic       1344
# ...

# %% [markdown]
# # How would you select  the elements in bold and italics from the array?

# %%
array  = np.array([[94, 89, 63],[93, 92, 48], [92, 94, 56]])
array
# Out:
# array([[94, 89, 63],
#        [93, 92, 48],
#        [92, 94, 56]])

# %%
get = array[ : 2, 1 : ]
get
# Out:
# array([[89, 63],
#        [92, 48]])

# %% [markdown]
# # Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
lowest_sum = food_balance[['Y2017', "Area"]]
lowest_sum
# Out:
#           Y2017      Area
# 0      41389.00   Algeria
# 1          0.00   Algeria
# 2       3341.00   Algeria
# 3         92.82   Algeria
# 4         80.19   Algeria
# ...         ...       ...
# 60938     19.00  Zimbabwe
# 60939      1.33  Zimbabwe
# 60940      1.00  Zimbabwe
# 60941      0.04  Zimbabwe
# 60942      0.02  Zimbabwe
#
# [60943 rows x 2 columns]

# %%
lowest_sum = food_balance.groupby("Area") ["Y2017"].sum()
lowest_sum
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %% [markdown]
# # What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
missing_data = food_balance.isnull().sum()
missing_data

# The total number and percentage of missing data in 2014 to 3 decimal places 1589 and 2.607%
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#Consider the following list of tuples:

y = [(2, 4), (7, 8), (1, 5, 9)]

#How would you assign element 8 from the list to a variable x?

x = y[1][1]
x
# Out:
# 8

# %%
#If you have the following list

lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ["Age","Nationality","Overall"]

#How do you create a pandas DataFrame using this list, to look like the table below?

dataframe = pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
dataframe
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92
